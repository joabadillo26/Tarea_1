# %% [markdown]
# Ejercicio 1:
#
# Desarrolla un programa que lea una variable de tipo  entera "value",indique si es numero par o impar.

# %%
value=float(input("Intruduce un numero"))
value_in=value %2
if value_in == 0:
  print("El numero",value,"es par" )
else:
    print("El numero",value,"es impar")
# Out:
# Intruduce un numero87
# El numero 87.0 es impar
